# %% [markdown]
# <a href="https://colab.research.google.com/github/sshikhar105/adversarialNLP/blob/main/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchtext transformers fastai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 39.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.8 MB/s eta 0:00:00
# ...

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 12.1 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

sst2 = load_dataset("glue", "sst2")
train_dataset = sst2['train']
validation_dataset = sst2['validation']
test_dataset = sst2['test']
# Out:
# ...
# Generating test split:   0%|          | 0/1821 [00:00<?, ? examples/s]

# %%
from datasets import load_dataset
from sklearn.model_selection import train_test_split

# Load the amazon_polarity dataset
amazon_reviews = load_dataset("amazon_polarity")
amazon_train_dataset = amazon_reviews['train']
amazon_test_dataset = amazon_reviews['test']

# Convert to lists
amazon_train_texts = [example['content'] for example in amazon_train_dataset]
amazon_train_labels = [example['label'] for example in amazon_train_dataset]

# Create a validation set by splitting the training data
amazon_train_texts, amazon_val_texts, amazon_train_labels, amazon_val_labels = train_test_split(
    amazon_train_texts, amazon_train_labels, test_size=0.1, random_state=42
)
# Out:
# ...
# Generating test split:   0%|          | 0/400000 [00:00<?, ? examples/s]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Download necessary NLTK datasets
nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('english'))
ps = PorterStemmer()

# Tokenization, removing stop words, and stemming
def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    filtered_tokens = [ps.stem(word) for word in tokens if word.isalnum() and word not in stop_words]
    return ' '.join(filtered_tokens)

# Assuming you have loaded SST2 and Amazon datasets into sst2_train_texts, amazon_train_texts, etc.
sst2_train_texts = [preprocess_text(text) for text in sst2_train_texts]
sst2_val_texts = [preprocess_text(text) for text in sst2_val_texts]
amazon_train_texts = [preprocess_text(text) for text in amazon_train_texts]
amazon_val_texts = [preprocess_text(text) for text in amazon_val_texts]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-498389ca5ff3> in <cell line: 21>()
#      19
#      20 # Assuming you have loaded SST2 and Amazon datasets into sst2_train_texts, amazon_train_texts, etc.
# ---> 21 sst2_train_texts = [preprocess_text(text) for text in sst2_train_texts]
#      22 sst2_val_texts = [preprocess_text(text) for text in sst2_val_texts]
#      23 amazon_train_texts = [preprocess_text(text) for text in amazon_train_texts]
#
# NameError: name 'sst2_train_texts' is not defined
